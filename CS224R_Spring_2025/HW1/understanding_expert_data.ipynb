# %%
import pickle

expert_path = '/home/sush/repos/human_learning_for_robot_learning/CS224R_Spring_2025/HW1/cs224r/policies/experts/Ant.pkl'

# %%
with open(expert_path, 'rb') as f:
    expert_data = pickle.load(f)
