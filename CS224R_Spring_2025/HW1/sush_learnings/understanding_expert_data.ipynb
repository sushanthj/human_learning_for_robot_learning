# %%
import pickle

expert_path = '/home/sush/repos/human_learning_for_robot_learning/CS224R_Spring_2025/HW1/cs224r/expert_data/expert_data_Hopper-v4.pkl'

# %%
with open(expert_path, 'rb') as f:
    expert_data = pickle.load(f)

# %%
expert_data[0].keys()
# Out:
# dict_keys(['observation', 'image_obs', 'reward', 'action', 'next_observation', 'terminal'])

# %%
expert_data[0]['observation'].shape
# Out:
# (1000, 11)

# %% [markdown]
# Based on the above exploration, it looks like each index in expert_data is a trajectory. Each trajectory further has multiple timesteps

# %%
expert_data[0]['action'].shape
# Out:
# (1000, 3)
